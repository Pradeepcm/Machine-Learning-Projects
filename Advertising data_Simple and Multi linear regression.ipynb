# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
#import statsmodel.api as sm

# %%
data = pd.read_csv("Advertising.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.drop(['Unnamed: 0'],axis=1)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(16,8))
plt.scatter(data['TV'],data['Sales'],c='blue')
plt.xlabel("Money spent on TV adds")
plt.ylabel({"TV sales"})
plt.show()

# %%
X= data['TV'].values.reshape(-1,1)
Y = data['Sales'].values.reshape(-1,1)

reg=LinearRegression()
reg.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.score(X,Y)
# Out:
# 0.611875050850071

# %%
#Multiple Linear Regression

# %%
Xs = data.drop(['Sales','Unnamed: 0'], axis=1)
y = data['Sales']

reg =LinearRegression()
reg.fit(Xs,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [ 0.04576465  0.18853002 -0.00103749]
# 2.938889369459412

# %%
reg.score(Xs,y)
# Out:
# 0.8972106381789521

# %%
# checking for all the other variables

# %%
X= data['TV'].values.reshape(-1,1)
Y = data['Sales'].values.reshape(-1,1)

reg=LinearRegression()
reg.fit(X,Y)
reg.score(X,Y)
# Out:
# 0.611875050850071

# %%
X= data['Radio'].values.reshape(-1,1)
Y = data['Sales'].values.reshape(-1,1)

reg=LinearRegression()
reg.fit(X,Y)
reg.score(X,Y)
# Out:
# 0.33203245544529525

# %%
X= data['Newspaper'].values.reshape(-1,1)
Y = data['Sales'].values.reshape(-1,1)

reg=LinearRegression()
reg.fit(X,Y)
reg.score(X,Y)
# Out:
# 0.05212044544430516

# %%
# TV has 61% Radio has 33% and News paper has onlt 5% effect on Sales hence we confirm that it is good to have on TV

# %%
# this can be used to find the co relation on how each variable has an effect on sales(each other).
data.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
np.corrcoef(data)
# Out:
# array([[ 1.        ,  0.65141109,  0.02661712, ...,  0.36019484,
#          0.67118405,  0.51648482],
#        [ 0.65141109,  1.        ,  0.74744861, ..., -0.29245062,
#          0.05444918, -0.15949142],
#        [ 0.02661712,  0.74744861,  1.        , ..., -0.64592565,
#         -0.44569508, -0.60728434],
#        ...,
#        [ 0.36019484, -0.29245062, -0.64592565, ...,  1.        ,
#          0.9295091 ,  0.98443355],
#        [ 0.67118405,  0.05444918, -0.44569508, ...,  0.9295091 ,
#          1.        ,  0.97546748],
#        [ 0.51648482, -0.15949142, -0.60728434, ...,  0.98443355,
#          0.97546748,  1.        ]])

# %%
plt.figure(figsize=(10,7))
import seaborn as sns
sns.heatmap(data.corr(),annot=True,linewidths=2)

# %%
plt.figure(figsize=(16,10))
sns.heatmap(np.corrcoef(data),annot=True,linewidths=2)
